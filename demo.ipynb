# %% [markdown]
# # Car Racing Environment Demo
#
# Part of project proposal for Aaron Dharna and Michael Tynes's Deep Learning course project.
#
# Note: If you wish to run this, make sure you have gym and gym\[box2d\] installed, which you can install by uncommenting the two lines below.

# %%
#!pip install -U gym

# %%
#!pip install -U gym[box2d]

# %%
import gym
import matplotlib.pyplot as plt
from IPython import display
import numpy as np

# %%
def show_state(env, step=0, name="", info=""):
    """Fn to visualize the agent playing the game in a notebook"""
    plt.figure(10)
    plt.clf()
    plt.imshow(env.render(mode="rgb_array")) # would state pixels help here? 
    plt.title("{} | Step: {} {}".format(name, step, info))
    plt.axis('off')
    display.clear_output(wait=True)
    display.display(plt.gcf())

# %% [markdown]
# A silly demo policy: this will just drive the car forward until it starts to spin out.

# %%
def full_speed_ahead():
    """Full gas, no brake, no steer"""
    gas = 1
    _break = 0
    steer = 0
    action = np.array([steer, gas, _break])
    
    return action

# %% [markdown]
# ## Demo
# **Note:** This will open up a window with a view of the environment. The view will likely look bad.
# Just ignore it when it pops up and instead watch the plot of the environment generated by `show_state` below.

# %%
env = gym.make("CarRacing-v0")

s = env.reset()

done = False
step = 0
while not done:
    step += 1
    action = full_speed_ahead()
    state, reward, done, info = env.step(action)
    show_state(env, step)

env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-08cb80d376e9> in <module>()
#       8     step += 1
#       9     action = full_speed_ahead()
# ---> 10     state, reward, done, info = env.step(action)
#      11     show_state(env, step)
#      12
#
# ~/anaconda3/lib/python3.6/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      29     def step(self, action):
#      30         assert self._episode_started_at is not None, "Cannot call env.step() before calling reset()"
# ---> 31         observation, reward, done, info = self.env.step(action)
#      32         self._elapsed_steps += 1
#      33
#
# ~/anaconda3/lib/python3.6/site-packages/gym/envs/box2d/car_racing.py in step(self, action)
#     303         self.t += 1.0/FPS
#     304
# --> 305         self.state = self.render("state_pixels")
#     306
#     307         step_reward = 0
#
# ~/anaconda3/lib/python3.6/site-packages/gym/envs/box2d/car_racing.py in render(self, mode)
#     369             self.render_road()
#     370             for geom in self.viewer.onetime_geoms:
# --> 371                 geom.render()
#     372             t.disable()
#     373             self.render_indicators(WINDOW_W, WINDOW_H)  # TODO: find why 2x needed, wtf
#
# ~/anaconda3/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in render(self)
#     155     def render(self):
#     156         for attr in reversed(self.attrs):
# --> 157             attr.enable()
#     158         self.render1()
#     159         for attr in self.attrs:
#
# ~/anaconda3/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in enable(self)
#     195         self.vec4 = vec4
#     196     def enable(self):
# --> 197         glColor4f(*self.vec4)
#     198
#     199 class LineStyle(Attr):
#
# ~/anaconda3/lib/python3.6/site-packages/pyglet/gl/lib.py in errcheck(result, func, arguments)
#      83     pass
#      84
# ---> 85 def errcheck(result, func, arguments):
#      86     if _debug_gl_trace:
#      87         try:
#
# KeyboardInterrupt:
